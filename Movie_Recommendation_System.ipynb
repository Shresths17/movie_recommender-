# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAKTI-swain/Final-project/blob/main/Movie_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#used libaries in the project
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#connect the dataset to a pandas dataframe
movies_data = pd.read_csv('movies.csv')
movies_data.head()
# Out:
#    index                      title certificate  runtime  \
# 0      1                     Freddy      UA 16+  124 min
# 1      2             An Action Hero           U  130 min
# 2      3                    Kantara          UA  148 min
# 3      4  Khakee: The Bihar Chapter      UA 13+   45 min
# 4      5                 Drishyam 2          UA  140 min
#
#                                   genre  \
# 0  Drama, Mystery, Thriller
# 1                    Action
# 2  Action, Adventure, Drama
# 3      Action, Crime, Drama
# 4     Crime, Drama, Mystery
#
#                                                 desc  rating   votes
# 0  The lines between love and obsession blur in t...     7.9  16,441
# 1  Youth Icon. Superstar. Action Hero. At the age...     8.1  15,690
# 2  It involves culture of Kambala and Bhootha Kol...     8.7  78,358
# 3  As a righteous cop pursues a merciless crimina...     8.3   4,464
# 4  A gripping tale of an investigation and a fami...     8.6  18,743

# %%
#no. of rows and columns in the data frame
movies_data.shape
# Out:
# (10000, 8)

# %%
#selecting the relevant features for recommendation
selected_features = ['genre','desc','rating','votes']
print(selected_features)
# Out:
# ['genre', 'desc', 'rating', 'votes']

# %%
#replacing the null values with null string

for feature in selected_features:
     movies_data[feature] = movies_data[feature].fillna('')

# %%
# Combine existing features, handling potential missing columns
combined_features = movies_data['genre'].astype(str) + ' ' + movies_data['desc'].astype(str) + ' ' + movies_data['rating'].astype(str) + ' ' + movies_data['votes'].astype(str)
print(combined_features)
# Out:
# 0       Drama, Mystery, Thriller             The lines...
# 1       Action             Youth Icon. Superstar. Acti...
# 2       Action, Adventure, Drama             It involv...
# 3       Action, Crime, Drama             As a righteou...
# 4       Crime, Drama, Mystery             A gripping t...
#                               ...
# 9995                 Action, Comedy, Drama
# 9996                         Drama, Family
# 9997             Action, Adventure, Comedy
# 9998                                 Drama
# 9999                                 Crime
# Length: 10000, dtype: object

# %%
#converting the text data to feature vectors
vectorizer= TfidfVectorizer()

# %%
feature_vectors= vectorizer.fit_transform(combined_features)
print(feature_vectors)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 237733 stored elements and shape (10000, 19837)>
#   Coords	Values
#   (0, 6016)	0.058099007077201927
#   (0, 11931)	0.14502822017681893
#   (0, 18051)	0.21316170457084885
#   (0, 17953)	0.05987953209629127
#   (0, 10534)	0.29737142109803744
#   (0, 3035)	0.16428272722180703
#   (0, 10682)	0.11417557536279699
#   (0, 1976)	0.12496979955940776
#   (0, 12491)	0.2661221738271596
#   (0, 3333)	0.3204429634844519
#   (0, 8783)	0.0715429355719832
#   (0, 18016)	0.14690747218971667
#   (0, 15179)	0.21694498267934328
#   (0, 12802)	0.30500961443490276
#   (0, 19576)	0.0929310044038085
#   (0, 18725)	0.31457547649130546
#   (0, 18493)	0.2567258591432835
#   (0, 16137)	0.29737142109803744
#   (0, 18465)	0.1909820916907644
#   (0, 181)	0.21909602514665963
#   (0, 605)	0.3094928280704285
#   (1, 17953)	0.07677830879682826
#   (1, 8783)	0.1375999128736728
#   (1, 1448)	0.1140316883409368
#   (1, 19766)	0.15369802066008814
#   :	:
#   (9986, 4452)	0.7095900229895048
#   (9988, 6016)	1.0
#   (9989, 6016)	1.0
#   (9990, 11931)	0.6859955012010418
#   (9990, 18051)	0.5041362646030758
#   (9990, 4923)	0.5246492152324153
#   (9991, 6016)	0.5469207655816869
#   (9991, 1448)	0.8371843740631699
#   (9992, 6016)	0.2972219142909323
#   (9992, 1564)	0.821048370180557
#   (9992, 15174)	0.48737942866834766
#   (9993, 6016)	0.40716389483453524
#   (9993, 1448)	0.6232552718594134
#   (9993, 15174)	0.6676604143145078
#   (9994, 6016)	1.0
#   (9995, 6016)	0.4181417023514885
#   (9995, 1448)	0.6400592579082733
#   (9995, 4452)	0.6445786710096058
#   (9996, 6016)	0.44045051269768754
#   (9996, 6872)	0.8977768909168603
#   (9997, 1448)	0.4355693700731073
#   (9997, 1564)	0.7860470598728986
#   (9997, 4452)	0.43864489455513833
#   (9998, 6016)	1.0
#   (9999, 4923)	1.0

# %%
#getting the similarity scores using cosine similarity
similarity = cosine_similarity(feature_vectors)
print(similarity)
# Out:
# [[1.         0.01444175 0.04714132 ... 0.         0.05809901 0.        ]
#  [0.01444175 1.         0.03495193 ... 0.04966871 0.         0.        ]
#  [0.04714132 0.03495193 1.         ... 0.11056719 0.03895791 0.        ]
#  ...
#  [0.         0.04966871 0.11056719 ... 1.         0.         0.        ]
#  [0.05809901 0.         0.03895791 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.         0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (10000, 10000)

# %%
#getting the movie name from the user
movie_name = input('Enter your favourite movie name: ')

# %%
#creating a list with all the movie names given in the dataset
list_of_all_titles = movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Freddy', 'An Action Hero', 'Kantara', 'Khakee: The Bihar Chapter', 'Drishyam 2', 'Qala', 'Bhediya', 'Goodbye', 'RRR (Rise Roar Revolt)', 'India Lockdown', 'Cat', 'Office Christmas Party', 'Chup', 'Dharavi Bank', 'Vadhandhi: The Fable of Velonie', 'Sita Ramam', 'Brahmastra Part One: Shiva', '1917', 'Nazar Andaaz', 'Love Today', 'College Romance', 'Monica O My Darling', 'Ready Player One', 'Mirzapur', 'Salaam Venky', 'Blurr', 'Ponniyin Selvan: I', 'Yashoda', 'DAMaN', 'Dhokha: Round D Corner', 'Godfather', 'The Help', 'Ram Setu', 'Raksha Bandhan', 'The Happening', '3 Idiots', 'HIT: The 2nd Case', 'Drishyam', 'Tanaav', 'Bridge of Spies', 'Mukhbir - The Story of a Spy', 'Monster', 'Vikram Vedha', 'Flames', 'Ghost in the Shell', 'The Turning', 'Breathe: Into the Shadows', 'Tumbbad', 'Finch', 'Dredd', 'Kumari', 'Life of Pi', 'Lincoln', 'Liger', 'Mismatched', 'Nitham Oru Vaanam', 'HIT: The First Case', 'Hit', 'The Girl on the Train', 'Lion', 'Uunchai', 'Kooman', 'Doctor G', 'Rorschach', 'Four More Shots Please!', 'Karthikeya 2', 'Laal Singh Chaddha', 'The Family Man', 'The Legend of Hanuman', 'Thank God', 'K.G.F: Chapter 2', 'I Am Number Four', 'The Bourne Supremacy', 'The Fall', 'Scam 1992: The Harshad Mehta Story', 'Padavettu', 'The Foreigner', 'Drishyam 2', 'Real Steel', 'The Trial of the Chicago 7', 'The BFG', 'War Horse', 'Cirkus', 'Bãhubali: The Beginning', 'Tapana', 'Panchayat', 'Crushed', 'Gandhi', 'Zakir Khan: Tathastu', 'Kabir Singh', 'Conan the Barbarian', 'Need for Speed', 'The Darjeeling Limited', 'Phone Bhoot', 'Iss Pyaar Ko Kya Naam Doon', 'Maarrich', 'Sacred Games', 'Kota Factory', 'Chhello Show', 'Cowboys & Aliens', '777 Charlie', 'Rocketry: The Nambi Effect', 'Major', 'TVF Pitchers', 'The Hundred-Foot Journey', 'Priest : The Whip and the Rise of the Evil', 'Pathaan', 'Pushpa: The Rise - Part 1', 'Gangubai Kathiawadi', 'Vikram', 'The Way Back', "A Dog's Purpose", 'Girls Hostel', 'Vadh', 'Jai Bhim', 'Fright Night', 'Cheppalani Undhi', 'Runway 34', 'Delhi Crime', 'Sultan', 'Jamtara: Sabka Number Ayega', 'Gold', 'Paatal Lok', 'Sardar', 'Tadka', 'Hostel Daze', 'Saudi Vellakka', 'Dobaaraa', 'Shooter', 'PK', 'The House with a Clock in Its Walls', 'Criminal Justice: Adhura Sach', 'Bulbbul', 'Baahubali 2: The Conclusion', 'Gatta Kusthi', 'Andhadhun', 'Shut In', 'Uri: The Surgical Strike', 'Miral', 'Lekh', 'The Kashmir Files', "A Dog's Journey", 'Special OPS', 'The Light Between Oceans', 'Dangerous', 'Mili', 'The White Tiger', 'Gangs of Wasseypur', 'Kaithi', 'Gullak', 'Apharan', 'Snowman', 'Suzhal - The Vortex', 'TVF Tripling', 'Dhoom:2', 'K.G.F: Chapter 1', 'Chhichhore', 'Faadu', 'Dangal', 'VR (Vikrant Rona)', 'Sir', 'All That Breathes', 'Jawan', 'The Teacher', 'Laila Majnu', 'Mastram', 'The Man Who Knew Infinity', 'ImMATURE', 'Ginna', 'Hush Hush', 'Darlings', 'The Reluctant Fundamentalist', 'Zindagi Na Milegi Dobara', 'Taare Zameen Par', 'Jug Jugg Jeeyo', 'Naagin', 'Kabhi Khushi Kabhie Gham...', 'Dilwale', 'She', 'Delivery Man', 'Dsp', 'Om Shanti Om', 'Maharani', 'Shiddat', 'Shamshera', 'Kal Ho Naa Ho', 'Kuch Kuch Hota Hai', 'Shershaah', 'Gadar: Ek Prem Katha', 'A Wednesday', 'Mimi', 'My Name Is Khan', 'Haseen Dillruba', 'Thiruchitrambalam', 'Bigg Boss', 'Badhaai Do', 'Cuttputlli', 'Smile', 'Raees', 'Stree', 'Dear Zindagi', 'Bimbisara', 'Batti Gul Meter Chalu', 'Khuda Haafiz Chapter II: Agni Pariksha', 'Har Har Mahadev', 'Moving in with Malaika', 'Come Play', 'Naai Sekar Returns', 'Pather Panchali', 'House of Secrets: The Burari Deaths', 'Comali', 'Swades: We, the People', 'Bullet to the Head', 'Aspirants', 'Jersey', 'Special Ops 1.5: The Himmat Story', 'Sardar Udham', 'Lagaan: Once Upon a Time in India', 'Mom', 'Devdas', 'Garuda Gamana Vrishabha Vahana', 'NCR Days', 'Mismatch', 'Lust Stories', 'Lucifer', 'Bride & Prejudice', 'Anek', 'Ek Villain Returns', 'Yeh Kaali Kaali Ankhein', 'Bajirao Mastani', 'Dilwale Dulhania Le Jayenge', 'Zero', 'Sonu Ke Titu Ki Sweety', 'Maja Ma', 'Jogi', 'Pratikshya', 'Tanhaji: The Unsung Warri ...

# %%
#finding the close match for the movie name given by user
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Drishyam 2', 'Drishyam 2', 'Drishya 2']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Drishyam 2

# %%
#finding the index of the movie with title
index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 5

# %%
#getting a list of similar moviesw
similarity_score = list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, np.float64(0.030650221134189963)), (1, np.float64(0.048102331252611874)), (2, np.float64(0.02030640415243494)), (3, np.float64(0.00567956663711696)), (4, np.float64(0.02490378370418208)), (5, np.float64(0.9999999999999997)), (6, np.float64(0.0372415898301996)), (7, np.float64(0.03831552302779992)), (8, np.float64(0.01185309929819672)), (9, np.float64(0.04897918908417745)), (10, np.float64(0.053281132114817276)), (11, np.float64(0.02026746765284812)), (12, np.float64(0.026598015882182267)), (13, np.float64(0.02418478133446586)), (14, np.float64(0.05211396151227088)), (15, np.float64(0.029438613642513448)), (16, np.float64(0.02271512663025966)), (17, np.float64(0.003942619677969218)), (18, np.float64(0.029792109509775552)), (19, np.float64(0.0075509941588476626)), (20, np.float64(0.0067554356003536944)), (21, np.float64(0.002543628831587063)), (22, np.float64(0.023974735967929674)), (23, np.float64(0.03431827965784333)), (24, np.float64(0.05220020405549485)), (25, np.float64(0.08100308390009836)), (26, np.float64(0.02138992327308957)), (27, np.float64(0.0)), (28, np.float64(0.01854067329913497)), (29, np.float64(0.04255728291818142)), (30, np.float64(0.02851971513948036)), (31, np.float64(0.03481506971014565)), (32, np.float64(0.026758979492923607)), (33, np.float64(0.05568822817696492)), (34, np.float64(0.005728175844982921)), (35, np.float64(0.029323892421456582)), (36, np.float64(0.025060396465662552)), (37, np.float64(0.03472294352745791)), (38, np.float64(0.02430791411319761)), (39, np.float64(0.0352161154108344)), (40, np.float64(0.009506100860485221)), (41, np.float64(0.01461141889676791)), (42, np.float64(0.006881049556955703)), (43, np.float64(0.02604078759850668)), (44, np.float64(0.03627412955050859)), (45, np.float64(0.05508393543449358)), (46, np.float64(0.01439069523532231)), (47, np.float64(0.0381985794640108)), (48, np.float64(0.01662626971672895)), (49, np.float64(0.02591481379146147)), (50, np.float64(0.018695567356834746)), (51, np.float64(0.021561035800781586)), (52, np.float64(0.05920609778507112)), (53, np.float64(0.026643704375770485)), (54, np.float64(0.039242440767637804)), (55, np.float64(0.06140210041561096)), (56, np.float64(0.04797117997478902)), (57, np.float64(0.014868293872499364)), (58, np.float64(0.023134128566851167)), (59, np.float64(0.01844265204573476)), (60, np.float64(0.021556187528780767)), (61, np.float64(0.012737411519684886)), (62, np.float64(0.02637736856202204)), (63, np.float64(0.03855908326342343)), (64, np.float64(0.028437159142433582)), (65, np.float64(0.05595213778695142)), (66, np.float64(0.01749896512194962)), (67, np.float64(0.013649092710021255)), (68, np.float64(0.00941233388102811)), (69, np.float64(0.023055246943339908)), (70, np.float64(0.011679815627092603)), (71, np.float64(0.009737611030446333)), (72, np.float64(0.0)), (73, np.float64(0.049487377518141355)), (74, np.float64(0.023017963224132316)), (75, np.float64(0.04534058287395106)), (76, np.float64(0.08006744103879179)), (77, np.float64(0.025788039911893372)), (78, np.float64(0.007328960693863527)), (79, np.float64(0.04461597405819575)), (80, np.float64(0.02478983128568687)), (81, np.float64(0.02207734605324209)), (82, np.float64(0.006275665906786454)), (83, np.float64(0.022091691302838678)), (84, np.float64(0.03134256080644364)), (85, np.float64(0.007746952847380103)), (86, np.float64(0.05014981309349875)), (87, np.float64(0.0668742085480944)), (88, np.float64(0.02149279798270963)), (89, np.float64(0.011510973679840431)), (90, np.float64(0.031757243195728035)), (91, np.float64(0.02742120553339533)), (92, np.float64(0.025865809311375942)), (93, np.float64(0.010178078012798967)), (94, np.float64(0.04269237924391711)), (95, np.float64(0.005002500663845844)), (96, np.float64(0.008097389664286633)), (97, np.float64(0.012453523289523118)), (98, np.float64(0.031974052866235565)), (99, np.float64(0.028435227945622827)), (100, np.float64(0.018979475153481258)), (101, np.float64(0.020645012767142125)), (102, np.float64 ...

# %%
len(similarity_score)
# Out:
# 10000

# %%
#sorting the movies based on their similarity score
sorted_similarity_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True)
print(sorted_similarity_movies)
# Out:
# [(5, np.float64(0.9999999999999997)), (6373, np.float64(0.18262152554411565)), (7389, np.float64(0.17763827230372853)), (9060, np.float64(0.17208488590080614)), (9309, np.float64(0.17208488590080614)), (1645, np.float64(0.16972351955245235)), (8961, np.float64(0.16466631226760062)), (9096, np.float64(0.16466631226760062)), (9185, np.float64(0.16466631226760062)), (9243, np.float64(0.16466631226760062)), (9307, np.float64(0.16466631226760062)), (9348, np.float64(0.16466631226760062)), (9363, np.float64(0.16466631226760062)), (9548, np.float64(0.16466631226760062)), (9718, np.float64(0.16466631226760062)), (9865, np.float64(0.16466631226760062)), (9895, np.float64(0.16466631226760062)), (9934, np.float64(0.16466631226760062)), (9949, np.float64(0.16466631226760062)), (9947, np.float64(0.16197609154518047)), (9977, np.float64(0.16197609154518047)), (4801, np.float64(0.15961769988593275)), (5296, np.float64(0.1585824000652253)), (9440, np.float64(0.15706054679454312)), (488, np.float64(0.1532358027749946)), (4381, np.float64(0.1532176677756456)), (9004, np.float64(0.14741546398708869)), (9532, np.float64(0.14645964114679474)), (9885, np.float64(0.14645964114679474)), (9970, np.float64(0.14627070085116686)), (5667, np.float64(0.14611160447384228)), (6173, np.float64(0.14584674033354744)), (4627, np.float64(0.14538712252605998)), (7541, np.float64(0.14318709087151046)), (6821, np.float64(0.14005479427738146)), (9144, np.float64(0.13955943730680717)), (2344, np.float64(0.1367468612966374)), (3545, np.float64(0.13273520091087115)), (6129, np.float64(0.13236922243715282)), (7704, np.float64(0.13114224608407457)), (1851, np.float64(0.13011862203783386)), (6513, np.float64(0.129738408594618)), (7500, np.float64(0.12965017596182765)), (6623, np.float64(0.12860723269190186)), (1871, np.float64(0.12664458790149705)), (8735, np.float64(0.12564907557222682)), (2112, np.float64(0.12494310859877136)), (2969, np.float64(0.12485165218601707)), (507, np.float64(0.12470285641843701)), (7803, np.float64(0.12441118864412737)), (5103, np.float64(0.12396724397014303)), (9789, np.float64(0.12344929317039988)), (9939, np.float64(0.12344929317039988)), (1357, np.float64(0.11972009460243511)), (9387, np.float64(0.11944975443767605)), (8202, np.float64(0.11899908728066302)), (2527, np.float64(0.1188269629508745)), (6799, np.float64(0.11875227425523324)), (2418, np.float64(0.11856603393399995)), (6816, np.float64(0.11840235840343297)), (5917, np.float64(0.1174840437621688)), (4390, np.float64(0.11737288866443513)), (4858, np.float64(0.11724164594036351)), (6617, np.float64(0.11718085786984751)), (5692, np.float64(0.11657582785571197)), (620, np.float64(0.11639823880846917)), (1409, np.float64(0.116379441043456)), (1267, np.float64(0.11608591362451279)), (2574, np.float64(0.11608355242108251)), (6306, np.float64(0.11596693740253626)), (3367, np.float64(0.11583958906356903)), (9115, np.float64(0.1156594736280985)), (5089, np.float64(0.11536137400856902)), (7602, np.float64(0.11534990326111995)), (9305, np.float64(0.11516337384308192)), (5942, np.float64(0.11508738379121794)), (9493, np.float64(0.11473992324330937)), (2781, np.float64(0.11467173976012221)), (1534, np.float64(0.11380551604790368)), (6180, np.float64(0.11377285466715445)), (6161, np.float64(0.11348781207121364)), (6694, np.float64(0.11309189032667577)), (7550, np.float64(0.11285898289910241)), (3154, np.float64(0.1125214968008475)), (6916, np.float64(0.11237750990023965)), (2050, np.float64(0.11212512569811137)), (9504, np.float64(0.11206807929896753)), (4816, np.float64(0.11160723516854432)), (723, np.float64(0.11156729969755709)), (2086, np.float64(0.11141020239833566)), (7107, np.float64(0.11071862320680281)), (4985, np.float64(0.11058264756259464)), (8372, np.float64(0.10952215378585839)), (2632, np.float64(0.10948088983125115)), (9417, np.float64(0.10859482932089622)), (4032, np.float64(0.10854269748333663)), (7797, np.float64(0.10847954349950488)), (1258, np.float64(0.10827198254459144)), ( ...

# %%
#print the name of similar movies based on the index
print('Movies suggested for you : \n')
i=1

for movie in sorted_similarity_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<11):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# 1 . Qala
# 2 . Na Umra Ki Seema Ho
# 3 . Kaaviya Thalaivan
# 4 . Geet Sangeet
# 5 . Rudra Veena
# 6 . Bhabhi Maa
# 7 . Dilpreet Dhillon Feat. Mehar Vaani: Nain
# 8 . Guru Randhawa: Lahore
# 9 . Mankirt Aulakh feat. Dj Flow: Badnam
# 10 . Jaise Savan
